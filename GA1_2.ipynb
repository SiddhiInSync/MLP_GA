# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddhiInSync/MLP_GA/blob/main/GA1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import numpy as np

# %%
data = pd.read_csv('Week1_GA_dataset.csv')

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#             Date  Year    Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009   Waterbury         111440.0    185000.0
# 1     2009-01-02  2009  Bridgeport         124670.0    150000.0
# 2     2009-01-02  2009   Waterbury          55720.0    140000.0
# 3     2009-01-02  2009  Bridgeport        4775276.0    272900.0
# 4     2009-01-02  2009  Bridgeport         112351.0    210000.0
# ...          ...   ...         ...              ...         ...
# 9995  2022-09-30  2022  Bridgeport         153660.0    322000.0
# 9996  2022-09-30  2022  Bridgeport         109820.0    340000.0
# 9997  2022-09-30  2022   Waterbury          83210.0    170000.0
# 9998  2022-09-30  2022         NaN         216420.0    415000.0
# 9999  2022-09-30  2022     Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...

# %% [markdown]
# Select all the even indexed rows from the given dataset.

# %%
df_new = df[df.index%2 ==0]

# %% [markdown]
#  What is the value in the 3rd indexed column of the 0th indexed row in the selected dataframe. (row/ column indexed from zero(0) in python/pandas)

# %%
df_new.iloc[0,3]
# Out:
# np.float64(111440.0)

# %% [markdown]
# Select all the even indexed rows from the given dataset. What is the value in the 3rd indexed column of the 332th indexed row in the selected dataframe. (row/ column indexed from zero(0))

# %%
df_odd_row = df[df.index%2 !=0]
df_odd_row.iloc[332,3]
# Out:
# np.float64(352940.0)

# %% [markdown]
# Select all the odd indexed columns from the given dataset. What is the value in the 5th indexed column of the 100th indexed row in the selected dataframe. (row/ column indexed from zero(0))

# %%
df_new1 = df.iloc[:,1::2]
df_new1.iloc[100,5]
# Out:
# 'West'

# %%
df_new1.iloc[332,3]
# Out:
# np.int64(6)

# %% [markdown]
# Select all the even indexed columns and even indexed rows from the given dataset. What is the value in the 3th indexed column of the 255th indexed row in the selected dataframe.

# %%
df_new2 = df.iloc[::2, ::2]
df_new2.iloc[255,3]
# Out:
# 'Detached House'

# %% [markdown]
# Determine the number of samples (rows) in the dataset that belong to the six most recent years, based on the provided data.

# %%
df['Date_column'] = pd.to_datetime(df['Date'])

# %%
df['year'] = df['Date_column'].dt.year

# %%
recent_years = df['year'].nlargest(6).unique()

# %%
sample_count = df[df['Year'].isin(recent_years)].value_counts().sum()
sample_count
# Out:
# np.int64(513)

# %% [markdown]
# Determine the number of samples (rows) in the dataset which has num_rooms = 3 and num_bathrooms = 3

# %%
count = len(df[(df['num_rooms']==3) & (df['num_bathrooms']==3)])
count
# Out:
# 2730

# %% [markdown]
# Determine the number of samples (rows) in the dataset which has num_rooms = 3 or num_bathrooms = 3

# %%
count = len(df[(df['num_rooms']==3) | (df['num_bathrooms']==3)])
count
# Out:
# 8591

# %% [markdown]
# In the Year 2022, how many houses (rows) located in the Greenwich Locality have exactly num_room == 3, and facing towards either the North or East?

# %%
count = len(df[(df['year']==2022) & (df['Locality']=='Greenwich') & (df['num_rooms']==3) & (df['Face'].isin(['North', 'East']))])
count
# Out:
# 42

# %% [markdown]
# Calculate the number of samples(rows) that correspond to the month of August across all the years.?

# %%
df['month'] = df['Date_column'].dt.month

# %%
count = len(df[df['month'] == 8])
count
# Out:
# 1050

# %%
According to the data which Locality have highest average Sale Price?

# %%
avg_sale = df.groupby('Locality')['Sale Price'].mean()

# %%
avg_sale.idxmax()
# Out:
# 'Greenwich'
