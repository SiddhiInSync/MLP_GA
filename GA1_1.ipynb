# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddhiInSync/MLP_GA/blob/main/GA1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Week1_GA_dataset.csv")

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#             Date  Year    Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009   Waterbury         111440.0    185000.0
# 1     2009-01-02  2009  Bridgeport         124670.0    150000.0
# 2     2009-01-02  2009   Waterbury          55720.0    140000.0
# 3     2009-01-02  2009  Bridgeport        4775276.0    272900.0
# 4     2009-01-02  2009  Bridgeport         112351.0    210000.0
# ...          ...   ...         ...              ...         ...
# 9995  2022-09-30  2022  Bridgeport         153660.0    322000.0
# 9996  2022-09-30  2022  Bridgeport         109820.0    340000.0
# 9997  2022-09-30  2022   Waterbury          83210.0    170000.0
# 9998  2022-09-30  2022         NaN         216420.0    415000.0
# 9999  2022-09-30  2022     Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...

# %% [markdown]
# What is the value present at the 692th indexed row and 0th indexed column in the data ?

# %%
df.iloc[692, 0]
# Out:
# '2009-11-16'

# %% [markdown]
# What is the value present at the 546th indexed row and 7th indexed column in the data ?

# %%
df.iloc[546,7]
# Out:
# np.int64(3)

# %% [markdown]
# How many unknown ("?) values are present in the dataset?

# %%
df.isin(['?']).value_counts()
# Out:
# Date   Year   Locality  Estimated Value  Sale Price  Property  Residential  num_rooms  num_bathrooms  carpet_area  property_tax_rate  Face
# False  False  False     False            False       False     False        False      False          False        False              False    8177
#                                                      True      False        False      False          False        False              False    1823
# Name: count, dtype: int64

# %% [markdown]
# What are the unique values present in the Locality feature of the dataset?

# %%
df['Locality'].unique()
# Out:
# array(['Waterbury', 'Bridgeport', 'Greenwich', 'Norwalk', nan,
#        'Fairfield', 'West Hartford', 'Stamford'], dtype=object)

# %% [markdown]
# Remove/Delete unknown ("?) values present in the dataset to make it null value.

# %%
df.replace('?', np.nan, inplace=True)

# %% [markdown]
# Which of the following features have missing(NaN) values present in the dataset?

# %%
Nan_val_per_column = df.isna().sum()
Nan_val_per_column
# Out:
# Date                    0
# Year                    0
# Locality             1253
# Estimated Value      1243
# Sale Price              0
# Property             1823
# Residential             0
# num_rooms               0
# num_bathrooms           0
# carpet_area          1229
# property_tax_rate       0
# Face                    0
# dtype: int64

# %% [markdown]
# Which of the following feature has most missing(NaN) values present in the dataset?
#  (Note: compute after removing "?")

# %%
Nan_val_per_column.idxmax()
# Out:
# 'Property'

# %% [markdown]
# Drop all the samples(rows) with missing values strictly greater than 2. How many samples remains after that ?

# %%
df.loc[df.isna().sum(axis=1) <= 2].shape
# Out:
# (9917, 12)

# %% [markdown]
# Drop all the samples(rows) with missing values in the original dataframe. How many samples remains after that ?

# %%
df.dropna()
# Out:
#             Date  Year       Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009      Waterbury         111440.0    185000.0
# 1     2009-01-02  2009     Bridgeport         124670.0    150000.0
# 2     2009-01-02  2009      Waterbury          55720.0    140000.0
# 3     2009-01-02  2009     Bridgeport        4775276.0    272900.0
# 5     2009-01-02  2009      Greenwich        2868880.0   3300000.0
# ...          ...   ...            ...              ...         ...
# 9986  2022-09-28  2022        Norwalk         305820.0    535000.0
# 9987  2022-09-28  2022        Norwalk         450510.0    677000.0
# 9993  2022-09-30  2022  West Hartford         121870.0    235000.0
# 9997  2022-09-30  2022      Waterbury          83210.0    170000.0
# 9999  2022-09-30  2022        Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...
